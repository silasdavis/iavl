# %%
l = open("bench.log","r").read().split("\n")[5:-3]
ts = [li.split("\t") for li in l]
f = lambda s: int("".join([i for i in s if i.isnumeric()]))

k = lambda s: s[s.index("(")+1:s.index(")")].split("_")
ts
vs = [(k(ti[0]), f(ti[2]), f(ti[3]), f(ti[4])) for ti in ts]
vs
# Out:
# [(['5', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['10', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['5', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   16777216),
#  (['10', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['5', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   16777216),
#  (['10', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['5', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   16777216),
#  (['10', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '5', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['5', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   16777216),
#  (['10', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '10', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464),
#  (['5', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   16777216),
#  (['10', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   35184372088832),
#  (['15', '15', '10', '10', '10', '10', 'goleveldb'],
#   ...,
#   ...,
#   73786976294838206464)]
